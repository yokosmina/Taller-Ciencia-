# %% [markdown]
# <a href="https://colab.research.google.com/github/yokosmina/Taller-Ciencia-/blob/main/Volados-taller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url ='https://raw.githubusercontent.com/yokosmina/Taller-Ciencia-/main/Volados.csv'
df = pd.read_csv(url)
df
# Out:
#     Try  H-ind  Weight-ind  H-lan  ...  Dist-flr-thm flr-type  sit-stand a/s
# 0     1    180          66     77  ...            64  granito    sentado   a
# 1     2    180          66     80  ...            64  granito    sentado   s
# 2     3    180          66     80  ...            64  granito    sentado   a
# 3     4    180          66     73  ...            64  granito    sentado   s
# 4     5    180          66     70  ...            64  granito    sentado   s
# ..  ...    ...         ...    ...  ...           ...      ...        ...  ..
# 95   96    170          89     15  ...           123     tela    sentado   s
# 96   97    170          89     35  ...           123     piel    sentado   a
# 97   98    170          89     70  ...           123  adoquin     parado   s
# 98   99    170          89     35  ...           123     piel    sentado   s
# 99  100    170          89     53  ...           123     peil     parado   a
#
# [100 rows x 10 columns]
